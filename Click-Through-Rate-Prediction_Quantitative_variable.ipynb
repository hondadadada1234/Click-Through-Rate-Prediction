# %% [markdown]
# - ランダムフォレスト
# - データ数　train.csv1000000
# - test.csv 1000000

# %%
kensu = 1000000
kensu_str = '1000000'
submit_csv_name = 'submit_Quantitative_variable_' + kensu_str + '.csv'

# %% [markdown]
# ## 必要なライブラリを読み込む

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## データ用が多いので、絞って読み込み

# %%
train_fname = 'train.csv'
reader = pd.read_csv(train_fname, chunksize=kensu)

# %%
df_train = reader.get_chunk(kensu)

# %%
df_train.shape
# Out:
# (1000000, 24)

# %%
df_train.head()
# Out:
#              id  click      hour    C1  banner_pos   site_id site_domain  \
# 0  1.000009e+18      0  14102100  1005           0  1fbe01fe    f3845767
# 1  1.000017e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 2  1.000037e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 3  1.000064e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 4  1.000068e+19      0  14102100  1005           1  fe8cc448    9166c161
#
#   site_category    app_id app_domain ...  device_type device_conn_type    C14  \
# 0      28905ebd  ecad2386   7801e8d9 ...            1                2  15706
# 1      28905ebd  ecad2386   7801e8d9 ...            1                0  15704
# 2      28905ebd  ecad2386   7801e8d9 ...            1                0  15704
# 3      28905ebd  ecad2386   7801e8d9 ...            1                0  15706
# 4      0569f928  ecad2386   7801e8d9 ...            1                0  18993
#
#    C15  C16   C17  C18  C19     C20  C21
# 0  320   50  1722    0   35      -1   79
# 1  320   50  1722    0   35  100084   79
# 2  320   50  1722    0   35  100084   79
# 3  320   50  1722    0   35  100084   79
# 4  320   50  2161    0   35      -1  157
#
# [5 rows x 24 columns]

# %%
df_train.columns
# Out:
# Index(['id', 'click', 'hour', 'C1', 'banner_pos', 'site_id', 'site_domain',
#        'site_category', 'app_id', 'app_domain', 'app_category', 'device_id',
#        'device_ip', 'device_model', 'device_type', 'device_conn_type', 'C14',
#        'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21'],
#       dtype='object')

# %% [markdown]
# ## データの欠損値、型、columnsを確認

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 24 columns):
# id                  1000000 non-null float64
# click               1000000 non-null int64
# hour                1000000 non-null int64
# C1                  1000000 non-null int64
# banner_pos          1000000 non-null int64
# site_id             1000000 non-null object
# site_domain         1000000 non-null object
# site_category       1000000 non-null object
# app_id              1000000 non-null object
# app_domain          1000000 non-null object
# app_category        1000000 non-null object
# device_id           1000000 non-null object
# device_ip           1000000 non-null object
# device_model        1000000 non-null object
# device_type         1000000 non-null int64
# device_conn_type    1000000 non-null int64
# C14                 1000000 non-null int64
# C15                 1000000 non-null int64
# C16                 1000000 non-null int64
# C17                 1000000 non-null int64
# C18                 1000000 non-null int64
# C19                 1000000 non-null int64
# C20                 1000000 non-null int64
# C21                 1000000 non-null int64
# dtypes: float64(1), int64(14), object(9)
# memory usage: 183.1+ MB

# %% [markdown]
# ## Numericalデータの統計情報

# %%
df_train.describe()
# Out:
#                  id           click          hour              C1  \
# count  1.000000e+06  1000000.000000  1.000000e+06  1000000.000000
# mean   9.376314e+18        0.160219  1.410210e+07     1005.088166
# std    5.236908e+18        0.366809  1.493256e+00        1.156928
# min    9.984920e+12        0.000000  1.410210e+07     1001.000000
# 25%    4.846660e+18        0.000000  1.410210e+07     1005.000000
# 50%    9.834387e+18        0.000000  1.410210e+07     1005.000000
# 75%    1.373053e+19        0.000000  1.410210e+07     1005.000000
# max    1.844670e+19        1.000000  1.410210e+07     1012.000000
#
#            banner_pos     device_type  device_conn_type             C14  \
# count  1000000.000000  1000000.000000    1000000.000000  1000000.000000
# mean         0.229922        1.025540          0.223363    18262.203151
# std          0.464627        0.453899          0.667164     3510.366302
# min          0.000000        0.000000          0.000000      375.000000
# 25%          0.000000        1.000000          0.000000    15707.000000
# 50%          0.000000        1.000000          0.000000    19251.000000
# 75%          0.000000        1.000000          0.000000    21153.000000
# max          7.000000        5.000000          5.000000    21705.000000
#
#                   C15             C16             C17             C18  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean       318.965808       56.495546     2041.031112        1.452262
# std         19.452897       36.546944      441.200965        1.362637
# min        120.000000       20.000000      112.000000        0.000000
# 25%        320.000000       50.000000     1722.000000        0.000000
# 50%        320.000000       50.000000     2161.000000        1.000000
# 75%        320.000000       50.000000     2420.000000        3.000000
# max       1024.000000     1024.000000     2497.000000        3.000000
#
#                   C19             C20             C21
# count  1000000.000000  1000000.000000  1000000.000000
# mean       190.779388    45505.857239       69.936118
# std        273.439286    49843.810147       38.513846
# min         33.000000       -1.000000       13.000000
# 25%         35.000000       -1.000000       43.000000
# 50%         39.000000       -1.000000       61.000000
# 75%        297.000000   100084.000000       79.000000
# max       1835.000000   100248.000000      195.000000

# %% [markdown]
# ## Categoricalデータの統計情報

# %%
df_train.describe(include=['O'])
# Out:
#          site_id site_domain site_category    app_id app_domain app_category  \
# count    1000000     1000000       1000000   1000000    1000000      1000000
# unique      2075        2030            21      2309        156           23
# top     85f751fd    c4e18dd6      50e219e0  ecad2386   7801e8d9     07d7df22
# freq      332893      348412        360056    667107     707429       679869
#
#        device_id device_ip device_model
# count    1000000   1000000      1000000
# unique     83431    313002         4581
# top     a99f214a  6b9769f2     8a4875bd
# freq      840265      5886        59771

# %% [markdown]
# ## hour列から　月、日、曜日、時を抜き出すために関数を用意

# %%
from datetime import datetime as dt
# hour列から　月、日、曜日、時を抜き出すために関数を用意

def get_month_from_time(x):
    time_date = dt.strptime(str(x), "%y%m%d%H")
    return time_date.month
def get_day_from_time(x):
    time_date = dt.strptime(str(x), "%y%m%d%H")
    return time_date.day
def get_weekday_from_time(x):
    time_date = dt.strptime(str(x), "%y%m%d%H")
    return time_date.weekday()
def get_hour_from_time(x):
    time_date = dt.strptime(str(x), "%y%m%d%H")
    return time_date.hour

# %%
def preprocess(df_train):
    
    # 上記で作成した関数をapplyで一括適用
    df_train["hour_month"] = df_train["hour"].apply(get_month_from_time)
    df_train["hour_day"] = df_train["hour"].apply(get_day_from_time)
    df_train["hour_weekday"] = df_train["hour"].apply(get_weekday_from_time)
    df_train["hour_hour"] = df_train["hour"].apply(get_hour_from_time)
   
    # カテゴリ変数からダミー変数の作成
    X = df_train.iloc[:, 0:28]
    colnames_categorical = ['site_id', 'site_domain','site_category', 'app_id', 'app_domain', 'app_category', 'device_id','device_ip', 'device_model']
#    X_dummy = pd.get_dummies(X[colnames_categorical])
#   X = pd.merge(X, X_dummy, left_index=True, right_index=True)
    X = X.drop(colnames_categorical, axis=1)
    
    
    return X

# %%
X = preprocess(df_train)

# %%
X
# Out:
#                   id  click      hour    C1  banner_pos  device_type  \
# 0       1.000009e+18      0  14102100  1005           0            1
# 1       1.000017e+19      0  14102100  1005           0            1
# 2       1.000037e+19      0  14102100  1005           0            1
# 3       1.000064e+19      0  14102100  1005           0            1
# 4       1.000068e+19      0  14102100  1005           1            1
# 5       1.000072e+19      0  14102100  1005           0            1
# 6       1.000072e+19      0  14102100  1005           0            1
# 7       1.000092e+19      0  14102100  1005           1            1
# 8       1.000095e+19      1  14102100  1005           0            1
# 9       1.000126e+19      0  14102100  1002           0            0
# 10      1.000187e+19      0  14102100  1005           1            1
# 11      1.000197e+19      0  14102100  1005           0            1
# 12      1.000203e+19      0  14102100  1005           0            1
# 13      1.000204e+19      0  14102100  1005           0            1
# 14      1.000252e+19      0  14102100  1005           0            1
# 15      1.000354e+19      0  14102100  1005           0            1
# 16      1.000359e+19      0  14102100  1005           0            1
# 17      1.000411e+19      0  14102100  1005           0            1
# 18      1.000418e+19      0  14102100  1005           1            1
# 19      1.000448e+19      0  14102100  1005           0            1
# 20      1.000451e+19      0  14102100  1005           0            1
# 21      1.000457e+19      0  14102100  1005           0            1
# 22      1.000467e+19      0  14102100  1005           0            1
# 23      1.000477e+19      1  14102100  1005           0            1
# 24      1.000525e+19      0  14102100  1005           0            1
# 25      1.000533e+19      0  14102100  1010           1            4
# 26      1.000554e+19      0  14102100  1005           1            1
# 27      1.000561e+19      1  14102100  1005           0            1
# 28      1.000565e+19      0  14102100  1005           0            1
# 29      1.000595e+19      0  14102100  1005           0            1
# ...              ...    ...       ...   ...         ...          ...
# 999970  1.474067e+19      0  14102105  1005           0            1
# 999971  1.474073e+19      0  14102105  1005           0            1
# 999972  1.474073e+19      0  14102105  1005           0            1
# 999973  1.474082e+19      0  14102105  1005           1            1
# 999974  1.474085e+19      0  14102105  1005           0            1
# 999975  1.474090e+19      0  14102105  1005           0            1
# 999976  1.474095e+19      0  14102105  1005           1            1
# 999977  1.474103e+19      0  14102105  1005           1            1
# 999978  1.474123e+19      0  14102105  1005           0            1
# 999979  1.474124e+19      0  14102105  1005           0            1
# 999980  1.474124e+19      0  14102105  1005           1            1
# 999981  1.474130e+19      0  14102105  1005           0            1
# 999982  1.474133e+19      1  14102105  1005           0            1
# 999983  1.474135e+19      0  14102105  1005           1            1
# 999984  1.474136e+19      1  14102105  1005           1            1
# 999985  1.474140e+19      0  14102105  1005           0            1
# 999986  1.474142e+19      1  14102105  1005           0            1
# 999987  1.474149e+19      0  14102105  1012           0            1
# 999988  1.474158e+19      0  14102105  1005           1            1
# 999989  1.474159e+19      0  14102105  1005           1            1
# 999990  1.474162e+18      0  14102105  1005           1            1
# 999991  1.474163e+19      0  14102105  1005           0            1
# 999992  1.474163e+19      0  14102105  1005           0            1
# 999993  1.474164e+19      0  14102105  1005           0            1
# 999994  1.474164e+19      1  14102105  1005           0            1
# 999995  1.474165e+19      0  14102105  1005           0            1
# 999996  1.474170e+19      0  14102105  1012           0            1
# 999997  1.474176e+17      0  14102105  1005           1            1
# 999998  1.474177e+19      0  14102105  1005           0            1
# 999999  1.474188e+19      0  14102105  1005           0            1
#
#         device_conn_type    C14  C15  C16   C17  C18  C19     C20  C21  \
# 0                      2  15706  320   50  1722    0   35      -1   79
# 1                      0  15704  320   50  1722    0   35  100084   79
# 2                      0  15704  320   50  1722    0   35  100084   79
# 3                      0  15706  320   50  1722    0   35  100084   79
# 4                      0  18993  320   50  2161    0   35      -1  157
# 5                      0  16920  320   50  1899    0  431  100077  117
# 6                      0  20362  320   50  2333    0   39      -1  157
# 7                      0  20632  320   50  2374    3   39      -1   23
# 8                      2  15707  320   50  1722    0   35      -1   79
# 9                      0  21689  320   50  2496    3  167  100191   23
# 10                     0  17747  320   50  1974    2   39  100019   33
# 11                     0  15701  320   50  1722    0   35      -1   79
# 12                     2  20596  320   50  2161    0   35  100148  157
# 13                     0  19771  320   50  2227    0  687  100077   48
# 14                     0  20984  320   50  2371    0  551      -1   46
# 15                     0  15699  320   50  1722    0   35  100084   79
# 16                     0  17914  320   50  2043    2   39      -1   32
# 17                     2  15708  320   50  1722    0   35  100084   79
# 18                     0   6558  320   50   571    2   39      -1   32
# 19                     0  21234  320   50  2434    3  163  100088   61
# 20                     0  20352  320   50  2333    0   39      -1  157
# 21                     0  15706  320   50  1722    0   35      -1   79
# 22                     0  20366  320   50  2333    0   39      -1  157
# 23                     0  15701  320   50  1722    0   35      -1   79
# 24                     0  15706  320   50  1722    0   35  100083   79
# 25                     0  21665  320   50  2493    3   35      -1  117
# 26                     0  20984  320   50  2371    0  551  100217   46
# 27                     0  21611  320   50  2480    3  297  100111   61
# 28                     0  20366  320   50  2333    0   39      -1  157
# 29                     0  15706  320   50  1722    0   35      -1   79
# ...                  ...    ...  ...  ...   ...  ...  ...     ...  ...
# 999970                 0  21684  320   50  2496    3  167  100199   23
# 999971                 0  21660  320   50  2446    3  171  100228  156
# 999972                 2  21647  320   50  2487    1  547  100183   51
# 999973                 0  15701  320   50  1722    0   35      -1   79
# 999974                 0  21664  320   50  2492    3   35      -1   43
# 999975                 0  21654  320   50  2489    1  547      -1   51
# 999976                 0  19251  320   50  2201    3   35      -1   43
# 999977                 0  19878  320   50  2271    0  687      -1   48
# 999978                 0  21611  320   50  2480    3  299  100111   61
# 999979                 0  19251  320   50  2201    3   35      -1   43
# 999980                 0  20596  320   50  2161    0   35      -1  157
# 999981                 0  21664  320   50  2492    3   35  100076   43
# 999982                 0  19493  320   50  2229    0  687  100031   48
# 999983                 0  17262  320   50  1872    3   39      -1   23
# 999984                 0  16920  320   50  1899    0  431  100074  117
# 999985                 2  21666  320   50  2494    3   35      -1  112
# 999986                 2  21666  320   50  2494    3   35      -1  112
# 999987                 2  21611  320   50  2480    3  299  100111   61
# 999988                 0  16071  320   50  1784    2  175      -1   95
# 999989                 0  20352  320   50  2333    0   39  100081  157
# 999990                 0  20362  320   50  2333    0   39  100077  157
# 999991                 0  15701  320   50  1722    0   35  100084   79
# 999992                 0  15701  320   50  1722    0   35  100083   79
# 999993                 0  19251  320   50  2201    3   35      -1   43
# 999994                 0  15707  320   50  1722    0   35      -1   79
# 999995                 0  15699  320   50  1722    0   35  100084   79
# 999996                 2  21612  320   50  2481    3  297  100111   61
# 999997                 0  15705  320   50  1722    0   35  100083   79
# 999998                 0  20366  320   50  2333    0   39      -1  157
# 999999                 3  21681  320   50  2496    3  167      -1   23
#
#         hour_month  hour_day  hour_weekday  hour_hour
# 0               10        21             1          0
# 1               10        21             1          0
# 2               10        21             1          0
# 3               10        21             1          0
# 4               10        21             1          0
# 5               10        21             1          0
# 6               10        21             1          0
# 7               10        21             1          0
# 8               10        21             1          0
# 9               10        21             1          0
# 10              10        21             1          0
# 11              10        21             1          0
# 12              10        21             1          0
# 13              10        21             1          0
# 14              10        21             1          0
# 15              10        21             1          0
# 16              10        21             1          0
# 17              10        21             1          0
# 18              10        21             1          0
# 19              10        21             1          0
# 20              10        21             1          0
# 21              10        21             1          0
# 22              10        21             1          0
# 23              10        21             1          0
# 24              10        21             1          0
# 25              10        21             1          0
# 26              10        21             1          0
# 27              10        21             1          0
# 28              10        21             1          0
# 29              10        21             1          0
# ...            ...       ...           ...        ...
# 999970          10        21             1          5
# 999971          10        21             1          5
# 999972          10        21             1          5
# 999973          10        21             1          5
# 999974          10        21             1          5
# 999975          10        21             1          5
# 999976          10        21             1          5
# 999977          10        21             1          5
# 999978          10        21             1          5
# 999979          10        21             1          5
# 999980          10        21             1          5
# 999981          10        21             1          5
# 999982          10        21             1          5
# 999983          10        21             1          5
# 999984          10        21             1          5
# 999985          10        21             1          5
# 999986          10        21             1          5
# 999987          10        21             1          5
# 999988          10        21             1          5
# 999989          10        21             1          5
# 999990          10        21             1          5
# 999991          10        21             1          5
# 999992          10        21             1          5
# 999993          10        21             1          5
# 999994          10        21             1          5
# 999995          10        21             1          5
# 999996          10        21             1          5
# 999997          10        21             1          5
# 999998          10        21             1          5
# 999999          10        21             1          5
#
# [1000000 rows x 19 columns]

# %% [markdown]
# ## ターゲット変数と特徴量を指定してsklearnに渡せるように準備する

# %%
target_col = 'click'
exclude_cols = ['click', 'id', 'hour']
feature_cols = [col for col in X.columns if col not in exclude_cols]

# %%
feature_cols
# Out:
# ['C1',
#  'banner_pos',
#  'device_type',
#  'device_conn_type',
#  'C14',
#  'C15',
#  'C16',
#  'C17',
#  'C18',
#  'C19',
#  'C20',
#  'C21',
#  'hour_month',
#  'hour_day',
#  'hour_weekday',
#  'hour_hour']

# %% [markdown]
# ## 説明変数（特徴量）

# %%
X[feature_cols].head()
# Out:
#      C1  banner_pos  device_type  device_conn_type    C14  C15  C16   C17  \
# 0  1005           0            1                 2  15706  320   50  1722
# 1  1005           0            1                 0  15704  320   50  1722
# 2  1005           0            1                 0  15704  320   50  1722
# 3  1005           0            1                 0  15706  320   50  1722
# 4  1005           1            1                 0  18993  320   50  2161
#
#    C18  C19     C20  C21  hour_month  hour_day  hour_weekday  hour_hour
# 0    0   35      -1   79          10        21             1          0
# 1    0   35  100084   79          10        21             1          0
# 2    0   35  100084   79          10        21             1          0
# 3    0   35  100084   79          10        21             1          0
# 4    0   35      -1  157          10        21             1          0

# %% [markdown]
# ## 被説明変数（ターゲット変数）

# %%
X[target_col].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: click, dtype: int64

# %%
y = np.array(X[target_col])
X = np.array(X[feature_cols])

# %%
y
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
X
# Out:
# array([[1005,    0,    1, ...,   21,    1,    0],
#        [1005,    0,    1, ...,   21,    1,    0],
#        [1005,    0,    1, ...,   21,    1,    0],
#        ...,
#        [1005,    1,    1, ...,   21,    1,    5],
#        [1005,    0,    1, ...,   21,    1,    5],
#        [1005,    0,    1, ...,   21,    1,    5]])

# %% [markdown]
# # モデルの作成

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.grid_search import GridSearchCV
from sklearn.cross_validation import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score

# %%
X_train, X_test, y_train, y_test = \
 train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
X_train1, X_train2, y_train1, y_train2 = \
 train_test_split(X_train, y_train, test_size=0.3, random_state=1234)

# %% [markdown]
# ## ランダムフォレスト

# %%
rf = RandomForestRegressor(random_state=1234)
rf.fit(X_train1, y_train1)
y_pred2 = rf.predict(X_train2)
rf_mse = mean_squared_error(y_train2, y_pred2)
print('Random Forest RMSE: ', np.sqrt(rf_mse))
# Out:
# Random Forest RMSE:  0.35263084502393416

# %%
print(accuracy_score(y_pred2.round(), y_train2,normalize=False))
# Out:
# 176092

# %% [markdown]
# ## 変数増加法で変数選択をしてみる

# %%
def get_gfs_feature_indices(X, y, features, clf):
    X_train_, X_test_, y_train_, y_test_ = \
        train_test_split(X, y, test_size=0.3, random_state=1234)
    
    #どの特徴量が何列目にあるかを辞書型で保持
    feature_indices = {feature: idx for idx, feature in enumerate(features)}
   
    # 特徴量をユニークにする
    features = set(features)
    
    # 評価（MSE）の初期化
    last_mse = np.inf
    
    #選ばれた特徴量を保存するための空集合を用意
    chosen_features = set()

    while len(chosen_features) < len(features):
        mse_features = []
        
        # 集合は引き算すると差集合
        for feature in (features - chosen_features):
            candidates = chosen_features.union(set([feature]))
            indices = [feature_indices[feature] for feature in candidates]
            clf.fit(X_train_[:, indices], y_train_)
            y_pred = clf.predict(X_test_[:, indices])
            mse = mean_squared_error(y_test_, y_pred)
            mse_features += [(mse, feature)]
        mse, feature = min(mse_features, key= lambda x:x[0])
        
        if mse >= last_mse:
            break
        last_mse = mse
        print('Newly Added Feature: {},\tRMSE Score: {}'.format(feature, np.sqrt(mse)))
        chosen_features.add(feature)
    return [feature_indices[feature] for feature in chosen_features]

# %%
selected_feature_index = \
get_gfs_feature_indices(X=X_train, 
                        y=y_train, 
                        features=feature_cols, 
                        clf=RandomForestRegressor(random_state=1234))
# Out:
# Newly Added Feature: C14,	RMSE Score: 0.3513395127162716
# Newly Added Feature: banner_pos,	RMSE Score: 0.35084999929389676
# Newly Added Feature: C1,	RMSE Score: 0.35049413324382167
# Newly Added Feature: device_conn_type,	RMSE Score: 0.35035492388431877
# Newly Added Feature: C19,	RMSE Score: 0.35032627481962014
# Newly Added Feature: C15,	RMSE Score: 0.3503059609306762
# Newly Added Feature: C18,	RMSE Score: 0.3502958681106884
# Newly Added Feature: device_type,	RMSE Score: 0.3502911198865362

# %% [markdown]
# ## 変数選択後の精度を確認

# %%
rf = RandomForestRegressor(random_state=1234)
rf.fit(X_train1[:, selected_feature_index], y_train1)
y_pred2 = rf.predict(X_train2[:, selected_feature_index])
rf_mse = mean_squared_error(y_train2, y_pred2)
print('RandomForest RMSE: ', np.sqrt(rf_mse))
# Out:
# RandomForest RMSE:  0.3502911198865362

# %%
print(accuracy_score(y_pred2.round(), y_train2,normalize=False))
# Out:
# 176631

# %%
rf = RandomForestRegressor(random_state=1234)

# %%
params = {'n_estimators': [10, 50, 100], 'max_depth': [5, 10, 50]}

# %%
import sklearn 
sklearn.__version__
# Out:
# '0.19.1'

# %%
#注意: scikit-learnのバージョンが、0.18の場合は、scoring='neg_mean_squared_error'とします
gscv = GridSearchCV(rf, param_grid=params, verbose=1,
                     cv=3, scoring='neg_mean_squared_error')

# %%
gscv.fit(X_train1[:, selected_feature_index], y_train1)
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:  8.2min finished
# GridSearchCV(cv=3, error_score='raise',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=1234, verbose=0, warm_start=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'n_estimators': [10, 50, 100], 'max_depth': [5, 10, 50]},
#        pre_dispatch='2*n_jobs', refit=True,
#        scoring='neg_mean_squared_error', verbose=1)

# %%
gscv.best_params_
# Out:
# {'max_depth': 10, 'n_estimators': 100}

# %% [markdown]
# ## パラメーターチューニング後のスコア

# %%
rf = RandomForestRegressor(n_estimators=100, max_depth=10, random_state=1234)
rf.fit(X_train1[:, selected_feature_index ], y_train1)
y_pred2 = rf.predict(X_train2[:, selected_feature_index])
rf_mse = mean_squared_error(y_train2, y_pred2)
print('RandomForest RMSE: ', np.sqrt(rf_mse))
# Out:
# RandomForest RMSE:  0.3503126039185984

# %%
print(accuracy_score(y_pred2.round(), y_train2,normalize=False))
# Out:
# 176640

# %% [markdown]
# ## テストデータへ適用して精度を確認する

# %%
rf = RandomForestRegressor(n_estimators=100, max_depth=10, random_state=1234)
rf.fit(X_train[:, selected_feature_index], y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=10,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#            oob_score=False, random_state=1234, verbose=0, warm_start=False)

# %%
y_pred_on_test = rf.predict(X_test[:, selected_feature_index])
rf_mse = mean_squared_error(y_test, y_pred_on_test)
print('RandomForest RMSE: ', np.sqrt(rf_mse))
# Out:
# RandomForest RMSE:  0.34883966223248064

# %%
print(accuracy_score(y_pred2.round(), y_train2,normalize=False))
# Out:
# 176640

# %% [markdown]
# ## submission用csvの作成

# %%
test_fname = 'test.csv'
reader_test = pd.read_csv(test_fname, chunksize=kensu)
df_test_origin = reader_test.get_chunk(kensu)

# %%
df_test = preprocess(df_test_origin)

# %%
selected_feature_index2 = [
'C14',
'banner_pos',
'C1',
'device_conn_type',
'C19',
'C15',
'C18',
'device_type'
]

# %%
submit_data =  pd.Series(rf.predict(df_test[selected_feature_index2]), name='click', index=df_test_origin['id'])
submit_data.to_csv(submit_csv_name, header=True)
